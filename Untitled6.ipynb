# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'titanic-passengers.csv',encoding="ISO-8859-1",sep=';')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull()#True ya3ny feh 7agat na2sa
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()#get the sum of missing data in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()# get the sum of missing data in all columns
# Out:
# 866

# %%
df['Cabin'].fillna(df['Cabin'].mode(),inplace=True)
df['Age'].fillna(df['Age'].mode(),inplace=True)
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000  B96 B98        S
# 1    male  25.0      0      0      348123   7.6500    F G73        S
# 2    male  20.0      0      0      350050   7.8542       G6        S
# 3  female  29.0      0      4      349909  21.0750      NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000      B71        S

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.loc[:,"Age"]
# Out:
# 0      28.000000
# 1      25.000000
# 2      20.000000
# 3      29.000000
# 4      31.000000
#          ...
# 886    14.000000
# 887    22.000000
# 888    30.000000
# 889    29.699118
# 890    19.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isnull().sum().sum()# After filling the age with the mean the sum of missing data is 687
# Out:
# 687

# %%
df.isnull()#no missing values in Age
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
import matplotlib.pyplot as plt
plt.title("Histogram of different ages")
plt.xlabel("Age")
df['Age'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of different ages'}, xlabel='Age', ylabel='Frequency'>

# %%
g=sns.FacetGrid(df,col='Sex')
g.map(plt.hist,'Age',bins=20)
#g.map(plt.hist,'Sex',bins=20)

# %%
grid = sns.FacetGrid(df,row="Sex", col="Survived", size=2.5, aspect=1.6)
grid.map(sns.histplot, "Age", alpha=.5)
grid.add_legend()
# Out:
# C:\Users\G A M I O N\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(df,row="Sex", col="Embarked", size=2.6, aspect=1.6)
grid.map(sns.histplot, "Age", alpha=.5)
grid.add_legend()
# Out:
# C:\Users\G A M I O N\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map(df)#the correlation is negative

# %%
#Use the groupby function combined with the mean() to view the relation between Pclass and survived 
#we cant to see the impact of Home Adress on the variable Promoted
cleanup={"Survived":{"yes":1, "no": 0}}  # at first, let's convert Promoted to numerical format
df.replace(cleanup, inplace=True)
df[["Pclass", "Survived"]].groupby(["Survived"], as_index=True).mean()
# Out:
#             Pclass
# Survived
# No        2.531876
# Yes       1.950292

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000  B96 B98        S
# 1    male  25.0      0      0      348123   7.6500    F G73        S
# 2    male  20.0      0      0      350050   7.8542       G6        S
# 3  female  29.0      0      4      349909  21.0750      NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000      B71        S

# %%
#full_name=df.Name.str.split(',', n = 1,expand=True)

#print(full_name)
df['titlef'] = df['Name'].str.split(' ', expand=True)[1]
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
Title_Dictionary = {

                    "Capt.":       "Officer",

                    "Col.":        "Officer",

                    "Major.":      "Officer",

                      "Dr.":         "Officer",

                    "Rev.":        "Officer",

                    "Jonkheer.":   "Royalty",

                    "Don.":        "Royalty",

                    "Sir." :       "Royalty",

                   "Lady." :      "Royalty",

                  "the Countess.": "Royalty",

                    "Dona.":       "Royalty",

                    "Mme.":        "Miss",

                    "Mlle.":       "Miss",

                    "Miss." :      "Miss",

                    "Ms.":         "Mrs",

                    "Mr." :        "Mrs",

                    "Mrs." :       "Mrs",

                    "Master." :    "Master"

                    }
df['titlef'].replace(Title_Dictionary,inplace=True)
df2=df['titlef'].replace()
#inplace changed it in the df
   #,['Capt.','Col.','Major.','Dr.','Rev.'],'Officer')

# %%
s = "Collander, Mr. Erik Gustaf"
s.split(" ")[1]
# Out:
# 'Mr.'

# %%
#{"Miss.","Mrs.","Officer."}in Title_Dictionary.values() 
#{"Miss","Mrs","Officer"} in df["titlef"].values
#a = ['Miss' , 'Officer','']

# %%
df["titlef"].value_counts()
# Out:
# Mrs             624
# Miss            182
# Master           40
# Officer          18
# y                 4
# Impe,             3
# Planke,           3
# Gordon,           2
# Royalty           2
# Pelsmaeker,       1
# the               1
# Walle,            1
# Shawah,           1
# Messemaeker,      1
# Billiard,         1
# Steen,            1
# der               1
# Carlo,            1
# Cruyssen,         1
# Melkebeke,        1
# Mulder,           1
# Velde,            1
# Name: titlef, dtype: int64

# %%
#df = df[df["titlef"].str.contains("Pelsmaeker,|the|Walle,|Shawah,| Messemaeker,|Billiard,|Steen,|der|Carlo,|Cruyssen,|Melkebeke,|Mulder,|Velde,|Planke,|Impe,|y|Messemaeker,|Gordon,") == False]

# %%
#df["titlef"].value_counts()

# %%
#grid = sns.FacetGrid(df, col="Sex", size=6, aspect=1.6)
#grid.map(sns.barplot, "titlef", 'Age', alpha=.5, ci=None)
#grid.add_legend()

# %%
df = df[df['titlef'].str.contains('Master|Officer|Mrs|Miss|Royalty')]
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
grid = sns.FacetGrid(df, col="Sex", size=6, aspect=1.6)
grid.map(sns.barplot, "titlef", 'Age', alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\G A M I O N\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\G A M I O N\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df["titlef"].value_counts()
# Out:
# Mrs        624
# Miss       182
# Master      40
# Officer     18
# Royalty      2
# Name: titlef, dtype: int64

# %%
sum_column = df["Parch"] + df["SibSp"]
df["FamilySize"] = sum_column
df
# Out:
# C:\Users\G A M I O N\AppData\Local\Temp\ipykernel_6224\3919570954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FamilySize"] = sum_column
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# ...

# %%
plt.title("Histogram of different family size")
plt.xlabel("FamilySize")
df['FamilySize'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of different family size'}, xlabel='FamilySize', ylabel='Frequency'>

# %%
#histogram shows us that as the number of people increase the possibilty for them to be from one family decrease.
